# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv('../data/Direct_Investment-related_Indicators.csv')
df.head()
# Out:
#    ObjectId    Country ISO2 ISO3  \
# 0         1  Argentina   AR  ARG
# 1         2  Argentina   AR  ARG
# 2         3  Argentina   AR  ARG
# 3         4  Argentina   AR  ARG
# 4         5  Argentina   AR  ARG
#
#                                            Indicator                Unit  \
# 0  CO2 emissions in exports of domestic controlle...  Metric tons of CO2
# 1  CO2 emissions in exports of domestic controlle...  Metric tons of CO2
# 2  CO2 emissions in exports of domestic controlle...  Metric tons of CO2
# 3  CO2 emissions in exports of domestic controlle...  Metric tons of CO2
# 4  CO2 emissions in exports of domestic controlle...  Metric tons of CO2
#
#                                               Source CTS_Code  \
# 0  OECD (2022), OECD FDI Statistics Database, htt...   ECBIXD
# 1  OECD (2022), OECD FDI Statistics Database, htt...   ECBIXD
# 2  OECD (2022), OECD FDI Statistics Database, htt...   ECBIXD
# 3  OECD (2022), OECD FDI Statistics Database, htt...   ECBIXD
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14190 entries, 0 to 14189
# Data columns (total 26 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ObjectId             14190 non-null  int64
#  1   Country              14190 non-null  object
#  2   ISO2                 14190 non-null  object
#  3   ISO3                 14190 non-null  object
#  4   Indicator            14190 non-null  object
#  5   Unit                 14190 non-null  object
#  6   Source               14190 non-null  object
#  7   CTS_Code             14190 non-null  object
#  8   CTS_Name             14190 non-null  object
#  9   CTS_Full_Descriptor  14190 non-null  object
#  10  Sector               14190 non-null  object
#  11  Scale                14190 non-null  object
#  12  F2005                13562 non-null  float64
#  13  F2006                13562 non-null  float64
#  14  F2007                13561 non-null  float64
# ...
